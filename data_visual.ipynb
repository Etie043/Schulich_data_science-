# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import f1_score, PrecisionRecallDisplay, precision_score, recall_score, roc_auc_score, RocCurveDisplay, roc_curve, confusion_matrix
from sklearn.linear_model import LogisticRegression
from datetime import timedelta
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install oct2py
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting oct2py
#   Downloading oct2py-5.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.12 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from oct2py) (1.26.4)
# Collecting octave-kernel>=0.34.0 (from oct2py)
#   Downloading octave_kernel-0.36.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: scipy>=0.17 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from oct2py) (1.13.0)
# Requirement already satisfied: ipykernel in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from octave-kernel>=0.34.0->oct2py) (6.29.4)
# Requirement already satisfied: jupyter-client>=4.3.0 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from octave-kernel>=0.34.0->oct2py) (8.6.1)
# Collecting metakernel>=0.24.0 (from octave-kernel>=0.34.0->oct2py)
#   Downloading metakernel-0.30.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (5.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (26.0.3)
# Requirement already satisfied: tornado>=6.2 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (6.4)
# Requirement already satisfied: traitlets>=5.3 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (5.14.3)
# Requirement already satisfied: jedi>=0.18 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py) (0.19.1)
# Collecting pexpect>=4.8 (from metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py)
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: comm>=0.1.1 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (8.24.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (1.6.0)
# Requirement already satisfied: packaging in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (24.0)
# Requirement already satisfied: psutil in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (5.9.8)
# Requirement already satisfied: decorator in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (4.11.0)
# Requirement already satisfied: colorama in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jedi>=0.18->metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (4.2.1)
# Requirement already satisfied: pywin32>=300 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (306)
# Collecting ptyprocess>=0.5 (from pexpect>=4.8->metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: six>=1.5 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\etiem\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.2.2)
# Downloading oct2py-5.7.2-py3-none-any.whl (29 kB)
# Downloading octave_kernel-0.36.0-py3-none-any.whl (35 kB)
# Downloading metakernel-0.30.2-py3-none-any.whl (217 kB)
#    ---------------------------------------- 0.0/217.8 kB ? eta -:--:--
#    ---------------------------------------- 217.8/217.8 kB 6.7 MB/s eta 0:00:00
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
#    ---------------------------------------- 0.0/63.8 kB ? eta -:--:--
#    ---------------------------------------- 63.8/63.8 kB 3.6 MB/s eta 0:00:00
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Installing collected packages: ptyprocess, pexpect, metakernel, octave-kernel, oct2py
# Successfully installed metakernel-0.30.2 oct2py-5.7.2 octave-kernel-0.36.0 pexpect-4.9.0 ptyprocess-0.7.0
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\etiem\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import oct2py as oclib
# Out:
# octave not found, please see README

# %%
year_list = [1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
       2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
type(year_list)
# Out:
# list

# %%
min(year_list)
# Out:
# 1994

# %%
josb_assets_list = [101.783,90.671,81.41,77.144,82.515,84.751,88.954,108.457,133.993,186.511,231.83,
                 304.832,368.392,440.098,491.366,556.364,662.037,813.612,894.847,935.738]
mw_assets_list = [160.494,204.105,295.478,379.415,403.732,611.195,707.734,717.869,769.313,869.198,993.322,
               1123.274,1096.952,1256.467,1187.73,1232.106,1320.318,1405.952,1496.347,1555.23]

# %%
plt.figure(figsize=(24,16), dpi= 40)
plt.plot(year_list,josb_assets_list,label="Joseph A Bank",linewidth=8)
plt.plot(year_list,mw_assets_list,'g-.',label="Men's Wearhouse",linewidth=8)
xtick_location = np.arange(1994,2013,6)
plt.xticks(ticks=xtick_location, rotation=0, fontsize=50, horizontalalignment='center')
plt.legend(bbox_to_anchor=(0.50, 0.95),fontsize=50)
plt.yticks(fontsize=50)
plt.grid(axis='both')
plt.xlabel('Year', fontsize = 65)
plt.ylabel('Total Assets', fontsize = 65)
# Out:
# Text(0, 0.5, 'Total Assets')

# %%
list_vec = [1,2,3,4]
list_vec + [1]
# Out:
# [1, 2, 3, 4, 1]

# %%
list_vec = [1,2,3,4]
list_vec.append(1)
list_vec
# Out:
# [1, 2, 3, 4, 1]

# %%
import numpy as np
array_vec = np.array([1,2,3,4])
array_vec + np.array([1])
# Out:
# array([2, 3, 4, 5])

# %%
#array([[ 1,  2,  3],
#       [ 0, -1,  2],
#       [ 1,  0,  4]])

#matrix_example[2][0]
#[2] is the last line since python counts from 0 so it is 1, 0, 4
#[0] is the first line 1, 2, 3

# %%
import scipy as sp

# %%
sp.stats.norm.pdf(14,10,2)
# Out:
# 0.02699548325659403

# %%
sp.stats.norm.cdf(14,10,2)
# Out:
# 0.9772498680518208

# %%
sp.stats.norm.isf(1-0.9772498680518208,10,2)
# Out:
# 14.0

# %%
sp.stats.norm.ppf(0.9772498680518208,10,2)
# this is the inverse 
# the area of the bell shaped curve is 0.977..
# 14 is the output
# Out:
# 14.0
